# %%
import cv2

# %%
from deepface import DeepFace

# %%
import matplotlib.pyplot as plt

# %%
img = cv2.imread('hb.jpg')

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:01<00:00,  2.93it/s]

# %%
predictions
# Out:
# [{'emotion': {'angry': 3.541123194422449e-07,
#    'disgust': 6.830110765861075e-14,
#    'fear': 2.8516709147432175e-06,
#    'happy': 99.93596673775116,
#    'sad': 2.1874683898941094e-07,
#    'surprise': 0.0012630142322943344,
#    'neutral': 0.06276002220503721},
#   'dominant_emotion': 'happy',
#   'region': {'x': 202, 'y': 129, 'w': 180, 'h': 180},
#   'face_confidence': 6.693222050962504,
#   'age': 36,
#   'gender': {'Woman': 4.81928214430809, 'Man': 95.18072009086609},
#   'dominant_gender': 'Man',
#   'race': {'asian': 22.325006127357483,
#    'indian': 12.06463873386383,
#    'black': 37.02822029590607,
#    'white': 3.628302738070488,
#    'middle eastern': 3.2679948955774307,
#    'latino hispanic': 21.685834228992462},
#   'dominant_race': 'black'}]

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
import cv2
  # Use this for displaying images in Colab

# Assuming 'img' is the image loaded using cv2.imread
# Assuming 'gray' is the grayscale version of the image
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = faceCascade.detectMultiScale(gray, 1.1, 4)

for (x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2)
    # Draw a green rectangle around the detected face

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
cv2.putText(img,
            predictions[0]['dominant_emotion'],  # Replace 0 with the correct index
            (0, 50),
            font, 1,
            (0, 0, 255),
            2,
            cv2.LINE_4)
# Out:
# array([[[213, 186, 129],
#         [213, 186, 129],
#         [213, 186, 129],
#         ...,
#         [204, 179, 115],
#         [204, 179, 115],
#         [204, 179, 115]],
#
#        [[213, 186, 129],
#         [213, 186, 129],
#         [213, 186, 129],
#         ...,
#         [204, 179, 115],
#         [204, 179, 115],
#         [204, 179, 115]],
#
#        [[213, 186, 129],
#         [213, 186, 129],
#         [213, 186, 129],
#         ...,
#         [204, 179, 115],
#         [204, 179, 115],
#         [204, 179, 115]],
#
#        ...,
#
#        [[210, 184, 124],
#         [210, 184, 124],
#         [210, 184, 124],
#         ...,
#         [209, 183, 116],
#         [209, 183, 116],
#         [209, 183, 116]],
#
#        [[210, 184, 124],
#         [210, 184, 124],
#         [210, 184, 124],
#         ...,
#         [209, 183, 116],
#         [209, 183, 116],
#         [209, 183, 116]],
#
#        [[210, 184, 124],
#         [210, 184, 124],
#         [210, 184, 124],
# ...

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
img1 = cv2.imread('aw.jpg')

# %%
plt.imshow(cv2.cvtColor(img1, cv2.COLOR_BGR2RGB))

# %%
c
# Out:
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:01<00:00,  2.49it/s]

# %%
predictions
# Out:
# [{'emotion': {'angry': 5.191519420833553,
#    'disgust': 0.003319780642018617,
#    'fear': 14.052882138066419,
#    'happy': 0.0006333977958187079,
#    'sad': 73.40922197158467,
#    'surprise': 0.0005603615015605568,
#    'neutral': 7.341859927288289},
#   'dominant_emotion': 'sad',
#   'region': {'x': 581, 'y': 530, 'w': 1072, 'h': 1072},
#   'face_confidence': 12.310347210092004,
#   'age': 31,
#   'gender': {'Woman': 99.99966621398926, 'Man': 0.00033665498904156266},
#   'dominant_gender': 'Woman',
#   'race': {'asian': 0.6828120909631252,
#    'indian': 8.765467256307602,
#    'black': 0.17934766365215182,
#    'white': 23.78459721803665,
#    'middle eastern': 43.67435276508331,
#    'latino hispanic': 22.91342467069626},
#   'dominant_race': 'middle eastern'},
#  {'emotion': {'angry': 0.05602161982096732,
#    'disgust': 2.921423172819182e-09,
#    'fear': 47.85967767238617,
#    'happy': 0.0013582241081167012,
#    'sad': 15.183930099010468,
# ...

# %%
import cv2

from deepface import DeepFace


faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

cap = cv2.VideoCapture(1)
if not cap.isOpened():
    cap = cv2.VideoCapture(0)
if not cap.isOpened():
    raise IOError("Cannot open webcam")

while True:
    ret, frame = cap.read()
    
    # Analyze emotion using DeepFace
    result = DeepFace.analyze(frame, actions=['emotion'], enforce_detection=False)
    
    # Use the predicted emotion from DeepFace
    result = predictions[0]['dominant_emotion']

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = faceCascade.detectMultiScale(gray, 1.1, 4)

    for (x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)

    font = cv2.FONT_HERSHEY_SIMPLEX

    # Display the predicted emotion on the frame
    cv2.putText(frame,
                predictions[0]['dominant_emotion'],
                (50, 50),
                font, 3,
                (0, 0, 255),
                2,
                cv2.LINE_AA)

    cv2.imshow('original video', frame)

    if cv2.waitKey(2) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# [[[ 61  53  41]
#   [ 61  53  43]
#   [ 61  52  45]
#   ...
#   [ 61  51  49]
#   [ 58  49  46]
#   [ 56  46  44]]
#
#  [[ 61  53  41]
#   [ 60  52  42]
#   [ 61  52  45]
#   ...
#   [ 60  50  47]
#   [ 58  49  45]
#   [ 57  48  44]]
#
#  [[ 61  53  41]
#   [ 60  52  41]
#   [ 61  53  44]
#   ...
#   [ 58  50  44]
#   [ 57  48  42]
#   [ 57  48  42]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [ 46  41  29]
#   [ 45  40  27]
#   [ 46  41  29]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [ 45  40  27]
#   [ 45  40  27]
#   [ 46  41  29]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [ 45  40  27]
#   [ 45  40  27]
#   [ 46  41  29]]]
# [[[ 59  56  44]
#   [ 58  55  43]
#   [ 58  55  43]
#   ...
#   [ 64  54  37]
#   [ 65  54  36]
#   [ 67  57  38]]
#
#  [[ 59  56  43]
#   [ 60  57  44]
#   [ 59  56  43]
#   ...
#   [ 63  54  37]
#   [ 64  54  37]
#   [ 65  56  38]]
#
#  [[ 58  55  41]
#   [ 60  58  44]
# ...
